# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf 
import seaborn as sb
import requests

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-ed5ef809-2206-4c25-974f-b370832a1376" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed5ef809-2206-4c25-974f-b370832a1376">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2020Products.xlsx to 2020Products (4).xlsx

# %%
in_2020 = pd.read_excel('2020Products.xlsx')
in_2020.head(10)
# Out:
#                                           Row Labels  Sum of Quantity
# 0  A Complete Text Book of ICSE Mathematics Part ...            167.0
# 1  A Complete Text Book of ICSE Mathematics Part ...            242.0
# 2                       A Treasury of Stories Book 2             86.0
# 3                               Adarsh Sulekh Book 1             68.0
# 4                               Adarsh Sulekh Book 2             99.0
# 5                               Adarsh Sulekh Book 3             53.0
# 6                               Adarsh Sulekh Book 4             68.0
# 7                               Adarsh Sulekh Book 5             73.0
# 8                    Advanced Radiant Readers Book 1             75.0
# 9                    Advanced Radiant Readers Book 2             45.0

# %%
in_2020 = in_2020.astype({'Sum of Quantity':'int'})
in_2020.head()
# Out:
#                                           Row Labels  Sum of Quantity
# 0  A Complete Text Book of ICSE Mathematics Part ...              167
# 1  A Complete Text Book of ICSE Mathematics Part ...              242
# 2                       A Treasury of Stories Book 2               86
# 3                               Adarsh Sulekh Book 1               68
# 4                               Adarsh Sulekh Book 2               99

# %%
products_2020= in_2020.sort_values(by="Sum of Quantity", ascending=False)
products_2020.head(10)
# Out:
#                                            Row Labels  Sum of Quantity
# 546             Simplified ICSE Chemistry for Std. IX            99719
# 547              Simplified ICSE Chemistry for Std. X            56083
# 79                                 Cotton Bag 14 x 16            29968
# 291               Material Board Art and Craft Book 5            26950
# 553  Simplified Middle School Chemistry for Std. VIII            25826
# 287               Material Board Art and Craft Book 1            25750
# 289               Material Board Art and Craft Book 3            25250
# 288               Material Board Art and Craft Book 2            25200
# 674                                WOW! Art & Craft 3            24438
# 290               Material Board Art and Craft Book 4            23750

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-3e20099f-8503-487a-9b33-fb048f548bd2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e20099f-8503-487a-9b33-fb048f548bd2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2021Products.xlsx to 2021Products (4).xlsx

# %%
in_2021 = pd.read_excel('2021Products.xlsx')
in_2021.head(10)
# Out:
#                                          Row Labels  Sum of Quantity
# 0              Simplified ICSE Chemistry for Std. X            26975
# 1             Simplified ICSE Chemistry for Std. IX            16653
# 2   Simplified Middle School Chemistry for Std. VII            12226
# 3  The Radiant Way Series (Chambers Ed.) First Step            11422
# 4  Simplified Middle School Chemistry for Std. VIII            11379
# 5    Simplified Middle School Chemistry for Std. VI            10911
# 6                    WOW! Mathematics - CBSE Book 5             6598
# 7             WOW! GK - World With In Worlds Book 4             6439
# 8                    WOW! Mathematics - CBSE Book 4             6433
# 9        The Radiant Way Series (Allied Ed.) Primer             6428

# %%
products_2021 = in_2021.sort_values(by="Sum of Quantity", ascending=False)
products_2021.head(10)
# Out:
#                                          Row Labels  Sum of Quantity
# 0              Simplified ICSE Chemistry for Std. X            26975
# 1             Simplified ICSE Chemistry for Std. IX            16653
# 2   Simplified Middle School Chemistry for Std. VII            12226
# 3  The Radiant Way Series (Chambers Ed.) First Step            11422
# 4  Simplified Middle School Chemistry for Std. VIII            11379
# 5    Simplified Middle School Chemistry for Std. VI            10911
# 6                    WOW! Mathematics - CBSE Book 5             6598
# 7             WOW! GK - World With In Worlds Book 4             6439
# 8                    WOW! Mathematics - CBSE Book 4             6433
# 9        The Radiant Way Series (Allied Ed.) Primer             6428

# %%
df_join = pd.merge(products_2020, products_2021, on='Row Labels')
df_join
# Out:
#                                            Row Labels  Sum of Quantity_x  \
# 0               Simplified ICSE Chemistry for Std. IX              99719
# 1                Simplified ICSE Chemistry for Std. X              56083
# 2                                  Cotton Bag 14 x 16              29968
# 3    Simplified Middle School Chemistry for Std. VIII              25826
# 4                                  WOW! Art & Craft 3              24438
# ..                                                ...                ...
# 720         WOW! GK - World With In Worlds TM  Book 7                  1
# 721                World Book Encyclopedia 2018 - 22V                  1
# 722            Worldbook Discovery Encyclopedia - 13V                  1
# 723                   Udita (Hindi Pathmala) - Part 4                  1
# 724         WOW! GK - World With In Worlds TM  Book 8                  1
#
#      Sum of Quantity_y
# 0                16653
# 1                26975
# ...

# %%
m = df_join.head(10)
m
# Out:
#                                          Row Labels  Sum of Quantity_x  \
# 0             Simplified ICSE Chemistry for Std. IX              99719
# 1              Simplified ICSE Chemistry for Std. X              56083
# 2                                Cotton Bag 14 x 16              29968
# 3  Simplified Middle School Chemistry for Std. VIII              25826
# 4                                WOW! Art & Craft 3              24438
# 5                                WOW! Art & Craft 1              22974
# 6                                WOW! Art & Craft 5              22853
# 7                 New Radiant Readers ICSE - Book 1              22455
# 8                                WOW! Art & Craft 4              22401
# 9                                WOW! Art & Craft 2              22381
#
#    Sum of Quantity_y
# 0              16653
# 1              26975
# 2               2586
# 3              11379
# 4                654
# 5               1023
# 6                480
# ...

# %%
m.rename(columns={'Row Labels':'Products','Sum of Quantity_x':'2020', 'Sum of Quantity_y':'2021'},inplace=True)
m
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                            Products   2020   2021
# 0             Simplified ICSE Chemistry for Std. IX  99719  16653
# 1              Simplified ICSE Chemistry for Std. X  56083  26975
# 2                                Cotton Bag 14 x 16  29968   2586
# 3  Simplified Middle School Chemistry for Std. VIII  25826  11379
# 4                                WOW! Art & Craft 3  24438    654
# 5                                WOW! Art & Craft 1  22974   1023
# 6                                WOW! Art & Craft 5  22853    480
# 7                 New Radiant Readers ICSE - Book 1  22455   3284
# ...

# %%
m.plot(title = 'Products' ,x = "Products", y = ["2020","2021"],kind="bar")
plt.show()

# %%
df_join1 = pd.merge(products_2021, products_2020, on='Row Labels')
df_join1
# Out:
#                                            Row Labels  Sum of Quantity_x  \
# 0                Simplified ICSE Chemistry for Std. X              26975
# 1               Simplified ICSE Chemistry for Std. IX              16653
# 2     Simplified Middle School Chemistry for Std. VII              12226
# 3    The Radiant Way Series (Chambers Ed.) First Step              11422
# 4    Simplified Middle School Chemistry for Std. VIII              11379
# ..                                                ...                ...
# 720                       Pallavi Hindi Reader Book 2                  1
# 721                       Pallavi Hindi Reader Book 3                  1
# 722                       Pallavi Hindi Reader Book 4                  1
# 723                       Pallavi Hindi Reader Book 5                  1
# 724              WOW! Maths 5 ICSE CMS Edition Term 2                  1
#
#      Sum of Quantity_y
# 0                56083
# 1                99719
# ...

# %%
n = df_join1.head(10)
n
# Out:
#                                          Row Labels  Sum of Quantity_x  \
# 0              Simplified ICSE Chemistry for Std. X              26975
# 1             Simplified ICSE Chemistry for Std. IX              16653
# 2   Simplified Middle School Chemistry for Std. VII              12226
# 3  The Radiant Way Series (Chambers Ed.) First Step              11422
# 4  Simplified Middle School Chemistry for Std. VIII              11379
# 5    Simplified Middle School Chemistry for Std. VI              10911
# 6                    WOW! Mathematics - CBSE Book 5               6598
# 7             WOW! GK - World With In Worlds Book 4               6439
# 8                    WOW! Mathematics - CBSE Book 4               6433
# 9        The Radiant Way Series (Allied Ed.) Primer               6428
#
#    Sum of Quantity_y
# 0              56083
# 1              99719
# 2              17849
# 3               5142
# 4              25826
# 5              18741
# 6              20328
# ...

# %%
n.rename(columns = {'Row Labels':'Products','Sum of Quantity_x':'2021', 'Sum of Quantity_y':'2020'}, inplace = True)
n.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                            Products   2021   2020
# 0              Simplified ICSE Chemistry for Std. X  26975  56083
# 1             Simplified ICSE Chemistry for Std. IX  16653  99719
# 2   Simplified Middle School Chemistry for Std. VII  12226  17849
# 3  The Radiant Way Series (Chambers Ed.) First Step  11422   5142
# 4  Simplified Middle School Chemistry for Std. VIII  11379  25826
# 5    Simplified Middle School Chemistry for Std. VI  10911  18741
# 6                    WOW! Mathematics - CBSE Book 5   6598  20328
# 7             WOW! GK - World With In Worlds Book 4   6439   9887
# ...

# %%
n.plot(title = 'Products' ,x = "Products", y = ["2021","2020"], kind="bar", )
plt.show()

# %%
a = pd.merge(in_2020, in_2021, on="Row Labels")
a.head()
# Out:
#                                           Row Labels  Sum of Quantity_x  \
# 0  A Complete Text Book of ICSE Mathematics Part ...                167
# 1  A Complete Text Book of ICSE Mathematics Part ...                242
# 2                               Adarsh Sulekh Book 1                 68
# 3                               Adarsh Sulekh Book 2                 99
# 4                               Adarsh Sulekh Book 3                 53
#
#    Sum of Quantity_y
# 0                126
# 1                137
# 2                 11
# 3                116
# 4                 11

# %%
a.rename(columns = {'Row Labels':'Products','Sum of Quantity_x':'2020', 'Sum of Quantity_y':'2021'}, inplace = True)
a
# Out:
#                                               Products  2020  2021
# 0    A Complete Text Book of ICSE Mathematics Part ...   167   126
# 1    A Complete Text Book of ICSE Mathematics Part ...   242   137
# 2                                 Adarsh Sulekh Book 1    68    11
# 3                                 Adarsh Sulekh Book 2    99   116
# 4                                 Adarsh Sulekh Book 3    53    11
# ..                                                 ...   ...   ...
# 720                                 Zoom! UKG Literacy  2446  1367
# 721                                 Zoom! UKG Numeracy  2196  1138
# 722                                  Zoom! UKG Phonics  1876  1229
# 723                                   Zoom! UKG Rhymes  2196   938
# 724                                Zoom! UKG Storybook  1876   938
#
# [725 rows x 3 columns]

# %%
sb.set(rc={'figure.figsize':(50,500)})
b = sb.heatmap(a[['2020','2021']])

# %%
c = pd.merge(in_2021, in_2020, on="Row Labels")
c
# Out:
#                                            Row Labels  Sum of Quantity_x  \
# 0                Simplified ICSE Chemistry for Std. X              26975
# 1               Simplified ICSE Chemistry for Std. IX              16653
# 2     Simplified Middle School Chemistry for Std. VII              12226
# 3    The Radiant Way Series (Chambers Ed.) First Step              11422
# 4    Simplified Middle School Chemistry for Std. VIII              11379
# ..                                                ...                ...
# 720              WOW! Maths 2 ICSE CMS Edition Term 1                  1
# 721              WOW! Maths 2 ICSE CMS Edition Term 2                  1
# 722              WOW! Maths 3 ICSE CMS Edition Term 2                  1
# 723              WOW! Maths 5 ICSE CMS Edition Term 1                  1
# 724              WOW! Maths 5 ICSE CMS Edition Term 2                  1
#
#      Sum of Quantity_y
# 0                56083
# 1                99719
# ...

# %%
c.rename(columns = {'Row Labels':'Products','Sum of Quantity_x':'2021', 'Sum of Quantity_y':'2020'}, inplace = True)
e = c.head(10)
e
# Out:
#                                            Products   2021   2020
# 0              Simplified ICSE Chemistry for Std. X  26975  56083
# 1             Simplified ICSE Chemistry for Std. IX  16653  99719
# 2   Simplified Middle School Chemistry for Std. VII  12226  17849
# 3  The Radiant Way Series (Chambers Ed.) First Step  11422   5142
# 4  Simplified Middle School Chemistry for Std. VIII  11379  25826
# 5    Simplified Middle School Chemistry for Std. VI  10911  18741
# 6                    WOW! Mathematics - CBSE Book 5   6598  20328
# 7             WOW! GK - World With In Worlds Book 4   6439   9887
# 8                    WOW! Mathematics - CBSE Book 4   6433  20584
# 9        The Radiant Way Series (Allied Ed.) Primer   6428  11976

# %%
sb.set(rc={'figure.figsize':(5,10)})
d = sb.heatmap(e[['2021','2020']])
