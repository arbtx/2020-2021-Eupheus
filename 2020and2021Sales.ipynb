# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf 
import seaborn as sb
import requests

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-c6343dc5-d176-4732-ac52-91a4bef795d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c6343dc5-d176-4732-ac52-91a4bef795d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2020Sales.xlsx to 2020Sales.xlsx

# %%
in_2020 = pd.read_excel('2020Sales.xlsx')
in_2020.head()
# Out:
#                Row Labels  Sum of Total after tax
# 0             A R Suresha               108678.30
# 1             Abhay Dubey               766066.20
# 2             Abhijit Sen              4620929.25
# 3         Abhilash Semwal              1202360.54
# 4  Aditee Sunny Pawar (D)               191988.35

# %%
pd.options.display.float_format = '₹{:,.2f}'.format
print(in_2020)
# Out:
#                  Row Labels  Sum of Total after tax
# 0               A R Suresha             ₹108,678.30
# 1               Abhay Dubey             ₹766,066.20
# 2               Abhijit Sen           ₹4,620,929.25
# 3           Abhilash Semwal           ₹1,202,360.54
# 4    Aditee Sunny Pawar (D)             ₹191,988.35
# ..                      ...                     ...
# 123   Vijay Singh Choudhary           ₹3,530,773.00
# 124  Vinodkumar Ramchandani           ₹1,259,188.20
# 125                  Vishal             ₹150,168.00
# 126            Vivek Bansal           ₹1,587,492.55
# 127         Vivekanand Ojha              ₹68,928.00
#
# [128 rows x 2 columns]

# %%
m = in_2020.sort_values(by='Sum of Total after tax', ascending=False)
m.head(10)
# Out:
#                  Row Labels  Sum of Total after tax
# 51             KVS Srinivas          ₹91,444,697.35
# 36              Gaurav Jain          ₹18,128,260.05
# 12              Amrik Singh          ₹16,390,592.95
# 113          Syed Azeem Ali          ₹14,627,728.55
# 25       Balachandra Shetty          ₹11,687,532.60
# 119      Ved Prakash Khatri          ₹11,099,132.69
# 20   Ashok Rajaram Yeligeti           ₹7,630,659.20
# 94              Rohit Kumar           ₹7,093,983.25
# 76            Piyush Sharma           ₹7,049,009.70
# 107           Somnath Sadhu           ₹6,494,266.35

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-d9d2b253-0334-420b-958b-09f4e5e275f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d9d2b253-0334-420b-958b-09f4e5e275f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2021Sales.xlsx to 2021Sales.xlsx

# %%
in_2021 = pd.read_excel('2021Sales.xlsx')
in_2021.head()
# Out:
#             Row Labels  Sum of Total after tax
# 0          A R Suresha           ₹1,029,579.50
# 1          Abhay Dubey             ₹390,202.21
# 2          Abhijit Sen           ₹3,273,101.45
# 3      Abhilash Semwal           ₹1,435,467.40
# 4  Aditi Bhaskar Gadge             ₹191,455.75

# %%
n = in_2021.sort_values(by="Sum of Total after tax", ascending = False)
n.head(10)
# Out:
#                  Row Labels  Sum of Total after tax
# 11              Amrik Singh           ₹8,463,205.90
# 96           Syed Azeem Ali           ₹8,157,474.00
# 75   Ramesh Kumar Choudhary           ₹7,629,105.65
# 79              Rohit Kumar           ₹6,718,224.90
# 44             KVS Srinivas           ₹5,246,731.50
# 66            Piyush Sharma           ₹4,795,229.60
# 59  Nilesh Dattaram Gaikwad           ₹4,380,843.00
# 23       Balachandra Shetty           ₹4,358,109.70
# 30           Digvijay Singh           ₹3,696,566.95
# 57               Neil David           ₹3,588,232.60

# %%
df_join = pd.merge(m,n,on="Row Labels")
df_join.head(10)
# Out:
#            Row Labels  Sum of Total after tax_x  Sum of Total after tax_y
# 0        KVS Srinivas            ₹91,444,697.35             ₹5,246,731.50
# 1         Gaurav Jain            ₹18,128,260.05             ₹1,971,193.05
# 2         Amrik Singh            ₹16,390,592.95             ₹8,463,205.90
# 3      Syed Azeem Ali            ₹14,627,728.55             ₹8,157,474.00
# 4  Balachandra Shetty            ₹11,687,532.60             ₹4,358,109.70
# 5  Ved Prakash Khatri            ₹11,099,132.69               ₹938,678.63
# 6         Rohit Kumar             ₹7,093,983.25             ₹6,718,224.90
# 7       Piyush Sharma             ₹7,049,009.70             ₹4,795,229.60
# 8       Somnath Sadhu             ₹6,494,266.35             ₹3,525,326.65
# 9         Vijay Gupta             ₹6,456,110.60             ₹2,193,553.30

# %%
k = df_join.head(10)
k
# Out:
#            Row Labels  Sum of Total after tax_x  Sum of Total after tax_y
# 0        KVS Srinivas            ₹91,444,697.35             ₹5,246,731.50
# 1         Gaurav Jain            ₹18,128,260.05             ₹1,971,193.05
# 2         Amrik Singh            ₹16,390,592.95             ₹8,463,205.90
# 3      Syed Azeem Ali            ₹14,627,728.55             ₹8,157,474.00
# 4  Balachandra Shetty            ₹11,687,532.60             ₹4,358,109.70
# 5  Ved Prakash Khatri            ₹11,099,132.69               ₹938,678.63
# 6         Rohit Kumar             ₹7,093,983.25             ₹6,718,224.90
# 7       Piyush Sharma             ₹7,049,009.70             ₹4,795,229.60
# 8       Somnath Sadhu             ₹6,494,266.35             ₹3,525,326.65
# 9         Vijay Gupta             ₹6,456,110.60             ₹2,193,553.30

# %%
k.rename(columns={'Row Labels':'Employee Name','Sum of Total after tax_x':'2020', 'Sum of Total after tax_y':'2021'},inplace=True)
k
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#         Employee Name           2020          2021
# 0        KVS Srinivas ₹91,444,697.35 ₹5,246,731.50
# 1         Gaurav Jain ₹18,128,260.05 ₹1,971,193.05
# 2         Amrik Singh ₹16,390,592.95 ₹8,463,205.90
# 3      Syed Azeem Ali ₹14,627,728.55 ₹8,157,474.00
# 4  Balachandra Shetty ₹11,687,532.60 ₹4,358,109.70
# 5  Ved Prakash Khatri ₹11,099,132.69   ₹938,678.63
# 6         Rohit Kumar  ₹7,093,983.25 ₹6,718,224.90
# 7       Piyush Sharma  ₹7,049,009.70 ₹4,795,229.60
# 8       Somnath Sadhu  ₹6,494,266.35 ₹3,525,326.65
# 9         Vijay Gupta  ₹6,456,110.60 ₹2,193,553.30

# %%
k.plot(title = 'Sales' ,x = "Employee Name", y = ["2020","2021"],kind="bar")
plt.show()

# %%
df_join = pd.merge(n,m,on="Row Labels")
df_join.head(10)
# Out:
#                 Row Labels  Sum of Total after tax_x  Sum of Total after tax_y
# 0              Amrik Singh             ₹8,463,205.90            ₹16,390,592.95
# 1           Syed Azeem Ali             ₹8,157,474.00            ₹14,627,728.55
# 2   Ramesh Kumar Choudhary             ₹7,629,105.65             ₹4,282,767.05
# 3              Rohit Kumar             ₹6,718,224.90             ₹7,093,983.25
# 4             KVS Srinivas             ₹5,246,731.50            ₹91,444,697.35
# 5            Piyush Sharma             ₹4,795,229.60             ₹7,049,009.70
# 6  Nilesh Dattaram Gaikwad             ₹4,380,843.00               ₹217,680.00
# 7       Balachandra Shetty             ₹4,358,109.70            ₹11,687,532.60
# 8           Digvijay Singh             ₹3,696,566.95             ₹4,021,281.70
# 9               Neil David             ₹3,588,232.60             ₹3,977,035.80

# %%
l = df_join.head(10)
l
# Out:
#                 Row Labels  Sum of Total after tax_x  Sum of Total after tax_y
# 0              Amrik Singh             ₹8,463,205.90            ₹16,390,592.95
# 1           Syed Azeem Ali             ₹8,157,474.00            ₹14,627,728.55
# 2   Ramesh Kumar Choudhary             ₹7,629,105.65             ₹4,282,767.05
# 3              Rohit Kumar             ₹6,718,224.90             ₹7,093,983.25
# 4             KVS Srinivas             ₹5,246,731.50            ₹91,444,697.35
# 5            Piyush Sharma             ₹4,795,229.60             ₹7,049,009.70
# 6  Nilesh Dattaram Gaikwad             ₹4,380,843.00               ₹217,680.00
# 7       Balachandra Shetty             ₹4,358,109.70            ₹11,687,532.60
# 8           Digvijay Singh             ₹3,696,566.95             ₹4,021,281.70
# 9               Neil David             ₹3,588,232.60             ₹3,977,035.80

# %%
l.rename(columns = {'Row Labels':'Employee Name','Sum of Total after tax_x':'2021', 'Sum of Total after tax_y':'2020'}, inplace = True)
l.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#              Employee Name          2021           2020
# 0              Amrik Singh ₹8,463,205.90 ₹16,390,592.95
# 1           Syed Azeem Ali ₹8,157,474.00 ₹14,627,728.55
# 2   Ramesh Kumar Choudhary ₹7,629,105.65  ₹4,282,767.05
# 3              Rohit Kumar ₹6,718,224.90  ₹7,093,983.25
# 4             KVS Srinivas ₹5,246,731.50 ₹91,444,697.35
# 5            Piyush Sharma ₹4,795,229.60  ₹7,049,009.70
# 6  Nilesh Dattaram Gaikwad ₹4,380,843.00    ₹217,680.00
# 7       Balachandra Shetty ₹4,358,109.70 ₹11,687,532.60
# 8           Digvijay Singh ₹3,696,566.95  ₹4,021,281.70
# 9               Neil David ₹3,588,232.60  ₹3,977,035.80

# %%
l.plot(title = 'Sales' ,x = "Employee Name", y = ["2021","2020"],kind="bar")
plt.show()
